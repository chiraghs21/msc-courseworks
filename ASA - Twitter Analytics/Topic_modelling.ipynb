# %% [markdown]
# ### Topic modelling
#
# Topic modeling is a technique used in natural language processing (NLP) to identify hidden themes or topics in a collection of documents. BERTOPIC is a recently introduced topic modeling algorithm that utilizes BERT (Bidirectional Encoder Representations from Transformers) language representation to generate topic embeddings. BERTOPIC is designed to provide a scalable and efficient way to perform topic modeling on large datasets with high accuracy.
#
# The following code uses BERTOPIC to extract topics from tweets.

# %%
# Installations
import sys
if 'google.colab' in sys.modules:
    # !pip install emoji --upgrade
    # !python -m spacy download en_core_web_lg
    # !pip install gensim
    # !pip install chart_studio
    # !pip install bertopic

# %%
# Required Libraries

#Base and Cleaning 
import json
import requests
import pandas as pd
import numpy as np
import emoji
import regex
import re
import string
from collections import Counter

#Visualizations
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt 
import chart_studio
import chart_studio.plotly as py 
import chart_studio.tools as tls

#Natural Language Processing (NLP)
import spacy
from spacy.tokenizer import Tokenizer
from pprint import pprint
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)

# %%
data = pd.read_csv("./facup_2k.csv")
df = pd.DataFrame(data['text'])

# %%
df
# Out:
#                                                    text
# 0     🎶 Hecky, Jack and Stuart McCalllll 🎶\n\n#sufc ...
# 1     Another amazing night at Old Trafford with the...
# 2     People talking shit on Garnarcho an 18 year ol...
# 3     Three days after they won the League Cup, Manc...
# 4     I'm 100% convinced that the ball is completely...
# ...                                                 ...
# 2587  🎫 Fancy going to see @BristolCity v @ManCity i...
# 2588  Goalkeeper #GordonBanks in the 1962/63 #FACup ...
# 2589  Prince Henry is introduced to the Huddersfield...
# 2590  @Jaylee20220 400 million new #football tactics...
# 2591  The 9 Clubs which lost the most FA Cup Semi-Fi...
#
# [2592 rows x 1 columns]

# %%
def give_emoji_free_text(text):
    """
    Removes emoji's from tweets
    Accepts:
        Text (tweets)
    Returns:
        Text (emoji free tweets)
    """
    return emoji.replace_emoji(text)

def url_free_text(text):
    '''
    Cleans text from urls
    '''
    text = re.sub(r'http\S+', '', text)
    return text

# Apply the function above and get tweets free of emoji's
call_emoji_free = lambda x: give_emoji_free_text(x)

# Apply `call_emoji_free` which calls the function to remove all emoji's
df['emoji_free_tweets'] = df['text'].apply(call_emoji_free)

#Create a new column with url free tweets
df['url_free_tweets'] = df['emoji_free_tweets'].apply(url_free_text)

# %%
df
# Out:
#                                                    text
# 0     🎶 Hecky, Jack and Stuart McCalllll 🎶\n\n#sufc ...  \
# 1     Another amazing night at Old Trafford with the...
# 2     People talking shit on Garnarcho an 18 year ol...
# 3     Three days after they won the League Cup, Manc...
# 4     I'm 100% convinced that the ball is completely...
# ...                                                 ...
# 2587  🎫 Fancy going to see @BristolCity v @ManCity i...
# 2588  Goalkeeper #GordonBanks in the 1962/63 #FACup ...
# 2589  Prince Henry is introduced to the Huddersfield...
# 2590  @Jaylee20220 400 million new #football tactics...
# 2591  The 9 Clubs which lost the most FA Cup Semi-Fi...
#
#                                       emoji_free_tweets
# 0      Hecky, Jack and Stuart McCalllll \n\n#sufc #t...  \
# 1     Another amazing night at Old Trafford with the...
# 2     People talking shit on Garnarcho an 18 year ol...
# 3     Three days after they won the League Cup, Manc...
# 4     I'm 100% convinced that the ball is completely...
# ...                                                 ...
# 2587   Fancy going to see @BristolCity v @ManCity in...
# 2588  Goalkeeper #GordonBanks in the 1962/63 #FACup ...
# 2589  Prince Henry is introduced to the Huddersfield...
# 2590  @Jaylee20220 400 million new #football tactics...
# 2591  The 9 Clubs which lost the most FA Cup Semi-Fi...
#
#                                         url_free_tweets
# 0      Hecky, Jack and Stuart McCalllll \n\n#sufc #t...
# 1     Another amazing night at Old Trafford with the...
# 2     People talking shit on Garnarcho an 18 year ol...
# 3     Three days after they won the League Cup, Manc...
# 4     I'm 100% convinced that the ball is completely...
# ...                                                 ...
# 2587   Fancy going to see @BristolCity v @ManCity in...
# 2588  Goalkeeper #GordonBanks in the 1962/63 #FACup ...
# 2589  Prince Henry is introduced to the Huddersfield...
# 2590  @Jaylee20220 400 million new #football tactics...
# 2591  The 9 Clubs which lost the most FA Cup Semi-Fi...
#
# [2592 rows x 3 columns]

# %%
# Load spacy
# Make sure to restart the runtime after running installations and libraries tab
nlp = spacy.load('en_core_web_lg')

# %%
# Tokenizer
tokenizer = Tokenizer(nlp.vocab)


# Custom stopwords
custom_stopwords = ['hi','\n','\n\n', '&', ' ', '.', '-', 'got', "it's", 'it’s', "i'm", 'i’m', 'im', 'want', 'like', '$', '@']

# Customize stop words by adding to the default list
STOP_WORDS = nlp.Defaults.stop_words.union(custom_stopwords)

# ALL_STOP_WORDS = spacy + gensim + wordcloud
ALL_STOP_WORDS = STOP_WORDS.union(stopwords)


tokens = []

for doc in tokenizer.pipe(df['url_free_tweets'], batch_size=500):
    doc_tokens = []    
    for token in doc: 
        if token.text.lower() not in STOP_WORDS:
            doc_tokens.append(token.text.lower())   
    tokens.append(doc_tokens)

# Makes tokens column
df['tokens'] = tokens

# %%
df
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                    text  \
# 0     🎶 Hecky, Jack and Stuart McCalllll 🎶\n\n#sufc ...
# 1     Another amazing night at Old Trafford with the...
# 2     People talking shit on Garnarcho an 18 year ol...
# 3     Three days after they won the League Cup, Manc...
# 4     I'm 100% convinced that the ball is completely...
# ...                                                 ...
# 2587  🎫 Fancy going to see @BristolCity v @ManCity i...
# 2588  Goalkeeper #GordonBanks in the 1962/63 #FACup ...
# 2589  Prince Henry is introduced to the Huddersfield...
# 2590  @Jaylee20220 400 million new #football tactics...
# 2591  The 9 Clubs which lost the most FA Cup Semi-Fi...
#
#                                       emoji_free_tweets  \
# 0      Hecky, Jack and Stuart McCalllll \n\n#sufc #t...
# 1     Another amazing night at Old Trafford with the...
# 2     People talking shit on Garnarcho an 18 year ol...
# 3     Three days after they won the League Cup, Manc...
# 4     I'm 100% convinced that the ball is completely...
# ...                                                 ...
# 2587   Fancy going to see @BristolCity v @ManCity in...
# 2588  Goalkeeper #GordonBanks in the 1962/63 #FACup ...
# 2589  Prince Henry is introduced to the Huddersfield...
# 2590  @Jaylee20220 400 million new #football tactics...
# 2591  The 9 Clubs which lost the most FA Cup Semi-Fi...
#
#                                         url_free_tweets  \
# 0      Hecky, Jack and Stuart McCalllll \n\n#sufc #t...
# 1     Another amazing night at Old Trafford with the...
# 2     People talking shit on Garnarcho an 18 year ol...
# 3     Three days after they won the League Cup, Manc...
# 4     I'm 100% convinced that the ball is completely...
# ...                                                 ...
# 2587   Fancy going to see @BristolCity v @ManCity in...
# 2588  Goalkeeper #GordonBanks in the 1962/63 #FACup ...
# 2589  Prince Henry is introduced to the Huddersfield...
# 2590  @Jaylee20220 400 million new #football tactics...
# 2591  The 9 Clubs which lost the most FA Cup Semi-Fi...
#
#                                                  tokens
# 0     [hecky,, jack, stuart, mccalllll, #sufc, #twit...
# 1     [amazing, night, old, trafford, little, man!, ...
# 2     [people, talking, shit, garnarcho, 18, year, o...
# 3     [days, won, league, cup,, manchester, united, ...
# 4     [100%, convinced, ball, completely, bounds, we...
# ...                                                 ...
# 2587  [fancy, going, @bristolcity, v, @mancity, #fac...
# 2588  [goalkeeper, #gordonbanks, 1962/63, #facup, se...
# 2589  [prince, henry, introduced, huddersfield, town...
# 2590  [@jaylee20220, 400, million, new, #football, t...
# 2591  [9, clubs, lost, fa, cup, semi-finals:, everto...
#
# [2592 rows x 4 columns]

# %%
# Make tokens a string again
df['tokens_back_to_text'] = [' '.join(map(str, l)) for l in df['tokens']]

def get_lemmas(text):
    '''Used to lemmatize the processed tweets'''
    lemmas = []
    
    doc = nlp(text)
    
    # Something goes here :P
    for token in doc: 
        if ((token.is_stop == False) and (token.is_punct == False)) and (token.pos_ != 'PRON'):
            lemmas.append(token.lemma_)
    
    return lemmas

df['lemmas'] = df['tokens_back_to_text'].apply(get_lemmas)

# %%
df
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                    text  \
# 0     🎶 Hecky, Jack and Stuart McCalllll 🎶\n\n#sufc ...
# 1     Another amazing night at Old Trafford with the...
# 2     People talking shit on Garnarcho an 18 year ol...
# 3     Three days after they won the League Cup, Manc...
# 4     I'm 100% convinced that the ball is completely...
# ...                                                 ...
# 2587  🎫 Fancy going to see @BristolCity v @ManCity i...
# 2588  Goalkeeper #GordonBanks in the 1962/63 #FACup ...
# 2589  Prince Henry is introduced to the Huddersfield...
# 2590  @Jaylee20220 400 million new #football tactics...
# 2591  The 9 Clubs which lost the most FA Cup Semi-Fi...
#
#                                       emoji_free_tweets  \
# 0      Hecky, Jack and Stuart McCalllll \n\n#sufc #t...
# 1     Another amazing night at Old Trafford with the...
# 2     People talking shit on Garnarcho an 18 year ol...
# 3     Three days after they won the League Cup, Manc...
# 4     I'm 100% convinced that the ball is completely...
# ...                                                 ...
# 2587   Fancy going to see @BristolCity v @ManCity in...
# 2588  Goalkeeper #GordonBanks in the 1962/63 #FACup ...
# 2589  Prince Henry is introduced to the Huddersfield...
# 2590  @Jaylee20220 400 million new #football tactics...
# 2591  The 9 Clubs which lost the most FA Cup Semi-Fi...
#
#                                         url_free_tweets  \
# 0      Hecky, Jack and Stuart McCalllll \n\n#sufc #t...
# 1     Another amazing night at Old Trafford with the...
# 2     People talking shit on Garnarcho an 18 year ol...
# 3     Three days after they won the League Cup, Manc...
# 4     I'm 100% convinced that the ball is completely...
# ...                                                 ...
# 2587   Fancy going to see @BristolCity v @ManCity in...
# 2588  Goalkeeper #GordonBanks in the 1962/63 #FACup ...
# 2589  Prince Henry is introduced to the Huddersfield...
# 2590  @Jaylee20220 400 million new #football tactics...
# 2591  The 9 Clubs which lost the most FA Cup Semi-Fi...
#
#                                                  tokens  \
# 0     [hecky,, jack, stuart, mccalllll, #sufc, #twit...
# 1     [amazing, night, old, trafford, little, man!, ...
# 2     [people, talking, shit, garnarcho, 18, year, o...
# 3     [days, won, league, cup,, manchester, united, ...
# 4     [100%, convinced, ball, completely, bounds, we...
# ...                                                 ...
# 2587  [fancy, going, @bristolcity, v, @mancity, #fac...
# 2588  [goalkeeper, #gordonbanks, 1962/63, #facup, se...
# 2589  [prince, henry, introduced, huddersfield, town...
# 2590  [@jaylee20220, 400, million, new, #football, t...
# 2591  [9, clubs, lost, fa, cup, semi-finals:, everto...
#
#                                     tokens_back_to_text  \
# 0     hecky, jack stuart mccalllll #sufc #twitterbla...
# 1     amazing night old trafford little man! @manutd...
# 2     people talking shit garnarcho 18 year old sad ...
# 3     days won league cup, manchester united trailed...
# 4     100% convinced ball completely bounds west ham...
# ...                                                 ...
# 2587  fancy going @bristolcity v @mancity #facup? we...
# 2588  goalkeeper #gordonbanks 1962/63 #facup semifin...
# 2589  prince henry introduced huddersfield town play...
# 2590  @jaylee20220 400 million new #football tactics...
# 2591  9 clubs lost fa cup semi-finals: everton (13) ...
#
#                                                  lemmas
# 0     [hecky, jack, stuart, mccalllll, sufc, twitter...
# 1     [amazing, night, old, trafford, little, man, @...
# 2     [people, talk, shit, garnarcho, 18, year, old,...
# 3     [day, win, league, cup, manchester, united, tr...
# 4     [100, convince, ball, completely, bound, west,...
# ...                                                 ...
# 2587  [fancy, go, @bristolcity, v, @mancity, facup, ...
# 2588  [goalkeeper, gordonbank, 1962/63, facup, semif...
# 2589  [prince, henry, introduce, huddersfield, town,...
# 2590  [@jaylee20220, 400, million, new, football, ta...
# 2591  [9, club, lose, fa, cup, semi, final, everton,...
#
# [2592 rows x 6 columns]

# %%
# Make lemmas a string again
df['lemmas_back_to_text'] = [' '.join(map(str, l)) for l in df['lemmas']]

# Tokenizer function
def tokenize(text):
    """
    Parses a string into a list of semantic units (words)
    Args:
        text (str): The string that the function will tokenize.
    Returns:
        list: tokens parsed out
    """
    # Removing url's
    pattern = r"http\S+"
    
    tokens = re.sub(pattern, "", text) # https://www.youtube.com/watch?v=O2onA4r5UaY
    tokens = re.sub('[^a-zA-Z 0-9]', '', text)
    tokens = re.sub('[%s]' % re.escape(string.punctuation), '', text) # Remove punctuation
    tokens = re.sub('\w*\d\w*', '', text) # Remove words containing numbers
    tokens = re.sub('\@*\!*\$*', '', text) # Remove @ ! $
    tokens = tokens.strip(',') # TESTING THIS LINE
    tokens = tokens.strip('?') # TESTING THIS LINE
    tokens = tokens.strip('!') # TESTING THIS LINE
    tokens = tokens.strip("'") # TESTING THIS LINE
    tokens = tokens.strip(".") # TESTING THIS LINE

    tokens = tokens.lower().split() # Make text lowercase and split it
    
    return tokens

# Apply tokenizer
df['lemma_tokens'] = df['lemmas_back_to_text'].apply(tokenize)

# %%
df
# Out:
#                                                    text
# 0     🎶 Hecky, Jack and Stuart McCalllll 🎶\n\n#sufc ...  \
# 1     Another amazing night at Old Trafford with the...
# 2     People talking shit on Garnarcho an 18 year ol...
# 3     Three days after they won the League Cup, Manc...
# 4     I'm 100% convinced that the ball is completely...
# ...                                                 ...
# 2587  🎫 Fancy going to see @BristolCity v @ManCity i...
# 2588  Goalkeeper #GordonBanks in the 1962/63 #FACup ...
# 2589  Prince Henry is introduced to the Huddersfield...
# 2590  @Jaylee20220 400 million new #football tactics...
# 2591  The 9 Clubs which lost the most FA Cup Semi-Fi...
#
#                                       emoji_free_tweets
# 0      Hecky, Jack and Stuart McCalllll \n\n#sufc #t...  \
# 1     Another amazing night at Old Trafford with the...
# 2     People talking shit on Garnarcho an 18 year ol...
# 3     Three days after they won the League Cup, Manc...
# 4     I'm 100% convinced that the ball is completely...
# ...                                                 ...
# 2587   Fancy going to see @BristolCity v @ManCity in...
# 2588  Goalkeeper #GordonBanks in the 1962/63 #FACup ...
# 2589  Prince Henry is introduced to the Huddersfield...
# 2590  @Jaylee20220 400 million new #football tactics...
# 2591  The 9 Clubs which lost the most FA Cup Semi-Fi...
#
#                                         url_free_tweets
# 0      Hecky, Jack and Stuart McCalllll \n\n#sufc #t...  \
# 1     Another amazing night at Old Trafford with the...
# 2     People talking shit on Garnarcho an 18 year ol...
# 3     Three days after they won the League Cup, Manc...
# 4     I'm 100% convinced that the ball is completely...
# ...                                                 ...
# 2587   Fancy going to see @BristolCity v @ManCity in...
# 2588  Goalkeeper #GordonBanks in the 1962/63 #FACup ...
# 2589  Prince Henry is introduced to the Huddersfield...
# 2590  @Jaylee20220 400 million new #football tactics...
# 2591  The 9 Clubs which lost the most FA Cup Semi-Fi...
#
#                                                  tokens
# 0     [hecky,, jack, stuart, mccalllll, #sufc, #twit...  \
# 1     [amazing, night, old, trafford, little, man!, ...
# 2     [people, talking, shit, garnarcho, 18, year, o...
# 3     [days, won, league, cup,, manchester, united, ...
# 4     [100%, convinced, ball, completely, bounds, we...
# ...                                                 ...
# 2587  [fancy, going, @bristolcity, v, @mancity, #fac...
# 2588  [goalkeeper, #gordonbanks, 1962/63, #facup, se...
# 2589  [prince, henry, introduced, huddersfield, town...
# 2590  [@jaylee20220, 400, million, new, #football, t...
# 2591  [9, clubs, lost, fa, cup, semi-finals:, everto...
#
#                                     tokens_back_to_text
# 0     hecky, jack stuart mccalllll #sufc #twitterbla...  \
# 1     amazing night old trafford little man! @manutd...
# 2     people talking shit garnarcho 18 year old sad ...
# 3     days won league cup, manchester united trailed...
# 4     100% convinced ball completely bounds west ham...
# ...                                                 ...
# 2587  fancy going @bristolcity v @mancity #facup? we...
# 2588  goalkeeper #gordonbanks 1962/63 #facup semifin...
# 2589  prince henry introduced huddersfield town play...
# 2590  @jaylee20220 400 million new #football tactics...
# 2591  9 clubs lost fa cup semi-finals: everton (13) ...
#
#                                                  lemmas
# 0     [hecky, jack, stuart, mccalllll, sufc, twitter...  \
# 1     [amazing, night, old, trafford, little, man, @...
# 2     [people, talk, shit, garnarcho, 18, year, old,...
# 3     [day, win, league, cup, manchester, united, tr...
# 4     [100, convince, ball, completely, bound, west,...
# ...                                                 ...
# 2587  [fancy, go, @bristolcity, v, @mancity, facup, ...
# 2588  [goalkeeper, gordonbank, 1962/63, facup, semif...
# 2589  [prince, henry, introduce, huddersfield, town,...
# 2590  [@jaylee20220, 400, million, new, football, ta...
# 2591  [9, club, lose, fa, cup, semi, final, everton,...
#
#                                     lemmas_back_to_text
# 0     hecky jack stuart mccalllll sufc twitterblade ...  \
# 1     amazing night old trafford little man @manutd ...
# 2     people talk shit garnarcho 18 year old sad sco...
# 3     day win league cup manchester united trail say...
# 4     100 convince ball completely bound west ham go...
# ...                                                 ...
# 2587  fancy go @bristolcity v @mancity facup pair ti...
# 2588  goalkeeper gordonbank 1962/63 facup semifinal ...
# 2589  prince henry introduce huddersfield town playe...
# 2590  @jaylee20220 400 million new football tactic r...
# 2591  9 club lose fa cup semi final everton 13 totte...
#
#                                            lemma_tokens
# 0     [hecky, jack, stuart, mccalllll, sufc, twitter...
# 1     [amazing, night, old, trafford, little, man, m...
# 2     [people, talk, shit, garnarcho, 18, year, old,...
# 3     [day, win, league, cup, manchester, united, tr...
# 4     [100, convince, ball, completely, bound, west,...
# ...                                                 ...
# 2587  [fancy, go, bristolcity, v, mancity, facup, pa...
# 2588  [goalkeeper, gordonbank, 1962/63, facup, semif...
# 2589  [prince, henry, introduce, huddersfield, town,...
# 2590  [jaylee20220, 400, million, new, football, tac...
# 2591  [9, club, lose, fa, cup, semi, final, everton,...
#
# [2592 rows x 8 columns]

# %%
from bertopic import BERTopic
topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True) # it is another approach to perform topic modeling
topics, probs = topic_model.fit_transform(df["tokens_back_to_text"])

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name
# 0      -1    787                        -1_facup_mufc_united_manutd
# 1       0    144                        0_fulham_home_trafford_mufc
# 2       1    122             1_grimsby_southampton_town_grimsbytown
# 3       2     88                     2_erik_europaleague_hag_europa
# 4       3     87                   3_garnacho_alejandro_goal_munwhu
# 5       4     79                       4_munwhu_weghorst_mufc_facup
# 6       5     75                                5_mufc_facup_way_la
# 7       6     66                           6_spurs_spursy_coys_thfc
# 8       7     58                       7_vs_blackburn_brighton_draw
# 9       8     51                               8_west_ham_31_united
# 10      9     49                              9_spuds_ffc_appear_oh
# 11     10     45             10_tottenham_sheffield_knocked_hotspur
# 12     11     39  11_wembley_wembleystadium_officialgtfc_papajoh...
# 13     12     38  12_sugaagustdtour_link_arseve_womenshistorymon...
# 14     13     37                            13_ggmu_ggmufc_cry_mood
# 15     14     36                           14_motson_john_motty_rip
# 16     15     36                   15_draw_home_alanshearer_shaping
# 17     16     34  16_sheffieldunited_sheffield_congratulations_t...
# 18     17     31                17_tickets_dm_mufctickets_available
# 19     18     31                  18_keane_roy_itvfootball_violence
# 20     19     31                     19_10_12_fleetwood_southampton
# 21     20     31                   20_blackburn_vs_burnley_brighton
# 22     21     30                21_bristol_bristolcity_mancity_city
# 23     22     26                         22_year_bhafc_brighton_win
# 24     23     26         23_tottenham_silverware_eliminated_drought
# 25     24     24                     24_manutd_manunited_week_great
# 26     25     23                          25_kane_harry_leave_spurs
# 27     26     23                      26_pastor_fred_prayer_closing
# 28     27     23                       27_fifth_matches_round_clubs
# 29     28     22           28_kompany_vincent_etihad_vincentkompany
# 30     29     21                29_spursofficial_spurs_blame_shutot
# 31     30     21                    30_ronaldo_messi_cristiano_fifa
# 32     31     19                 31_everton_saka_martinelli_sanchez
# 33     32     19                          32_ways_28_february_stoke
# 34     33     18                        33_leeds_fulhamfc_28th_lufc
# 35     34     18              34_blackburn_sufc_minutes_performance
# 36     35     17                      35_agarnacho7_boy_talent_star
# 37     36     16                36_shutot_shit_expressions_shambles
# 38     37     15                     37_next_draw_reds_quarterfinal
# 39     38     15                38_kompany_vincent_burnley_kompanys
# 40     39     15                         39_rovers_allowed_draw_try
# 41     40     15                         40_gw26_fpl_soulei_rodgers
# 42     41     14          41_emiratesfacup_queseraserapod_ties_plan
# 43     42     14                  42_guardiola_pep_via_jackflintham
# 44     43     14                      43_free_bettingtips_bets_cash
# 45     44     14                              44_utd_man_treble_wtf
# 46     45     13       45_twitterclarets_twitterblades_fucking_away
# 47     46     13                  46_homeofsoccer_day_wednesday_mar
# 48     47     13                 47_fred_contributions_season_maybe
# 49     48     13                        48_magic_cup_saps_bedsheets
# 50     49     13              49_burnleyofficial_burnley_rishi_ones
# 51     50     13             50_spursofficial_thfc_calamity_mistake
# 52     51     12                               51_lfc_cpfc_nufc_cfc
# 53     52     12                        52_mentality_steve_hag_erik
# 54     53     11                        53_semifinal_draw_home_cups
# 55     54     11       54_westham_eliminated_during_theatreofdreams
# 56     55     11                      55_burnley_city_8000_hattrick

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="0f257c8d-9e9f-4673-9e58-a71389c76708" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f257c8d-9e9f-4673-9e58-a71389c76708")) {                    Plotly.newPlot(                        "0f257c8d-9e9f-4673-9e58-a71389c76708",                        [{"customdata":[[0,"fulham | home | trafford | mufc | old",144],[1,"grimsby | southampton | town | grimsbytown | gtfc",122],[2,"erik | europaleague | hag | europa | manchesterunited",88],[3,"garnacho | alejandro | goal | munwhu | viva",87],[4,"munwhu | weghorst | mufc | facup | game",79],[5,"mufc | facup | way | la | love",75],[6,"spurs | spursy | coys | thfc | kart",66],[7,"vs | blackburn | brighton | draw | burnley",58],[8,"west | ham | 31 | united | manchester",51],[9,"spuds | ffc | appear | oh | facup",49],[10,"tottenham | sheffield | knocked | hotspur | 10",45],[11,"wembley | wembleystadium | officialgtfc | papajohnstrophy | final",39],[12,"sugaagustdtour | link | arseve | womenshistorymonth2023 | loveisland",38],[13,"ggmu | ggmufc | cry | mood | ddg",37],[14,"motson | john | motty | rip | johnmotson",36],[15,"draw | home | alanshearer | shaping | ever",36],[16,"sheffieldunited | sheffield | congratulations | totterats | perennial",34],[17,"tickets | dm | mufctickets | available | mufcspares",31],[18,"keane | roy | itvfootball | violence | roykeane",31],[19,"10 | 12 | fleetwood | southampton | 31",31],[20,"blackburn | vs | burnley | brighton | sheffield",31],[21,"bristol | bristolcity | mancity | city | tomorrow",30],[22,"year | bhafc | brighton | win | fa",26],[23,"tottenham | silverware | eliminated | drought | meanwhile",26],[24,"manutd | manunited | week | great | win",24],[25,"kane | harry | leave | spurs | selection",23],[26,"pastor | fred | prayer | closing | matiangi",23],[27,"fifth | matches | round | clubs | 202223",23],[28,"kompany | vincent | etihad | vincentkompany | returning",22],[29,"spursofficial | spurs | blame | shutot | disgrace",21],[30,"ronaldo | messi | cristiano | fifa | garnacho",21],[31,"everton | saka | martinelli | sanchez | delivery",19],[32,"ways | 28 | february | stoke | reach",19],[33,"leeds | fulhamfc | 28th | lufc | pizza",18],[34,"blackburn | sufc | minutes | performance | wouldve",18],[35,"agarnacho7 | boy | talent | star | generational",17],[36,"shutot | shit | expressions | shambles | rant",16],[37,"next | draw | reds | quarterfinal | mufc",15],[38,"kompany | vincent | burnley | kompanys | etihad",15],[39,"rovers | allowed | draw | try | bbcfacup",15],[40,"gw26 | fpl | soulei | rodgers | bgw25",15],[41,"emiratesfacup | queseraserapod | ties | plan | round",14],[42,"guardiola | pep | via | jackflintham | exceptional",14],[43,"free | bettingtips | bets | cash | premierleague",14],[44,"utd | man | treble | wtf | played",14],[45,"twitterclarets | twitterblades | fucking | away | sufc",13],[46,"homeofsoccer | day | wednesday | mar | lights",13],[47,"fred | contributions | season | maybe | lichamartinez",13],[48,"magic | cup | saps | bedsheets | speculating",13],[49,"burnleyofficial | burnley | rishi | ones | political",13],[50,"spursofficial | thfc | calamity | mistake | coys",13],[51,"lfc | cpfc | nufc | cfc | whufc",12],[52,"mentality | steve | hag | erik | mcclaren",12],[53,"semifinal | draw | home | cups | giving",11],[54,"westham | eliminated | during | theatreofdreams | haggy",11],[55,"burnley | city | 8000 | hattrick | mahrez",11]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>%{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[144,122,88,87,79,75,66,58,51,49,45,39,38,37,36,36,34,31,31,31,31,30,26,26,24,23,23,23,22,21,21,19,19,18,18,17,16,15,15,15,15,14,14,14,14,13,13,13,13,13,13,12,12,11,11,11]," ...
